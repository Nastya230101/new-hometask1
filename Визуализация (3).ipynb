# %%
# ДЗ Визуализация датасет 
#датасет https://www.kaggle.com/datasets/rajkumarpandey02/list-of-world-cities-by-population-density?resource=download

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
import matplotlib as plt
import matplotlib as mpl
import matplotlib.cm as cm 
import matplotlib.pyplot as plt
from matplotlib import pyplot

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c037766f-e081-448d-9a43-26ba44e2fe75" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c037766f-e081-448d-9a43-26ba44e2fe75">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df2 = pd.read_csv(io.BytesIO(uploaded['List of world cities by population density.csv']))
df2.head(10)
# Out:
#    Unnamed: 0              City    Population Area (km²) Area (mi²)  \
# 0           0              Malé    153,904[1]   1.956[1]      0.755
# 1           1            Manila  1,660,714[2]   38.55[3]      14.88
# 2           2             Bogor    866,034[4]   21.56[5]       8.32
# 3           3          Titagarh    124,213[6]    3.24[7]       1.25
# 4           4         Baranagar    250,768[6]    7.12[7]       2.75
# 5           5         Serampore    197,857[6]    5.88[7]       2.27
# 6           6      South Dumdum    392,444[6]   13.54[7]       5.23
# 7           7         Kamarhati    314,507[6]   10.96[7]       4.23
# 8           8           Kolkata  5,138,208[8]     185[9]       71.4
# 9           9  Levallois-Perret    66,082[10]   2.41[10]       0.93
#
#    Density (/km²)  Density (/mi²)      Country
# 0           78683        203846.0     Maldives
# 1           43079        111576.0  Philippines
# 2           40169        104037.0    Indonesia
# ...

# %%
df2.describe(include = "all")
# Out:
#         Unnamed: 0  City  Population Area (km²) Area (mi²)  Density (/km²)  \
# count     50.00000    50          50         50         50       50.000000
# unique         NaN    50          50         50         49             NaN
# top            NaN  Malé  153,904[1]   1.956[1]      19.98             NaN
# freq           NaN     1           1          1          2             NaN
# mean      24.50000   NaN         NaN        NaN        NaN    24374.940000
# std       14.57738   NaN         NaN        NaN        NaN     9923.133389
# min        0.00000   NaN         NaN        NaN        NaN    15718.000000
# 25%       12.25000   NaN         NaN        NaN        NaN    19083.250000
# 50%       24.50000   NaN         NaN        NaN        NaN    22245.000000
# 75%       36.75000   NaN         NaN        NaN        NaN    25776.250000
# max       49.00000   NaN         NaN        NaN        NaN    78683.000000
#
#         Density (/mi²) Country
# count        50.000000      50
# ...

# %%
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      50 non-null     int64
#  1   City            50 non-null     object
#  2   Population      50 non-null     object
#  3   Area (km²)      50 non-null     object
#  4   Area (mi²)      50 non-null     object
#  5   Density (/km²)  50 non-null     int64
#  6   Density (/mi²)  50 non-null     float64
#  7   Country         50 non-null     object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 3.2+ KB
# None

# %%
missing_data = df2.isnull()
missing_data.head(4)
# Out:
#    Unnamed: 0   City  Population  Area (km²)  Area (mi²)  Density (/km²)  \
# 0       False  False       False       False       False           False
# 1       False  False       False       False       False           False
# 2       False  False       False       False       False           False
# 3       False  False       False       False       False           False
#
#    Density (/mi²)  Country
# 0           False    False
# 1           False    False
# 2           False    False
# 3           False    False

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print(missing_data[column].value_counts())
    print(" ")
# Out:
# Unnamed: 0
# False    50
# Name: Unnamed: 0, dtype: int64
#
# City
# False    50
# Name: City, dtype: int64
#
# Population
# False    50
# Name: Population, dtype: int64
#
# Area (km²)
# False    50
# Name: Area (km²), dtype: int64
#
# Area (mi²)
# False    50
# Name: Area (mi²), dtype: int64
#
# Density (/km²)
# False    50
# Name: Density (/km²), dtype: int64
#
# Density (/mi²)
# False    50
# Name: Density (/mi²), dtype: int64
#
# Country
# False    50
# Name: Country, dtype: int64

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0        0
# City              0
# Population        0
# Area (km²)        0
# Area (mi²)        0
# Density (/km²)    0
# Density (/mi²)    0
# Country           0
# dtype: int64

# %%
#пропущенных колонок нет

# %%
plt.hist(df2['Country'], color = 'green', edgecolor = 'black',
         bins = 15)
sns.distplot(df2['Country'],
             bins = 15, color = 'green')
plt.title('Histogram of Country')
plt.ylabel('population')

Text(0, 0.5, 'population')
# Out:
# <ipython-input-41-cd40a43e4d7d>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2['Country'],
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-cd40a43e4d7d> in <cell line: 3>()
#       1 plt.hist(df2['Country'], color = 'green', edgecolor = 'black',
#       2          bins = 15)
# ----> 3 sns.distplot(df2['Country'],
#       4              bins = 15, color = 'green')
#       5 plt.title('Histogram of Country')
#
# ...

# %%
#самая большая плотность населения в Индии

# %%
#плотность населения по странам
labels = ['Индия','Филлипины','Другие']
values = [44,12,44]
colors = ['yellow','green','red']
plt.pie(values,labels=labels,colors=colors)
plt.axis('equal')
plt.show()
